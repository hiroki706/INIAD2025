# %% [markdown]
# ## Removal of seasonality

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ### Parameters

# %%
csv_in = './prec_tokyo_since2011-utf8.csv'

# %% [markdown]
# ### Read CSV file

# %%
df_season = pd.read_csv(csv_in, delimiter=',', skiprows=1, header=0)
df_season['Date'] = pd.to_datetime(df_season['Date'])
print(df_season.shape)
print(df_season.info())
display(df_season.head())
# Out:
# (2922, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2922 non-null   datetime64[ns]
#  1   Prec(mm)  2922 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 45.8 KB
# None
#         Date  Prec(mm)
# 0 2011-01-01       0.0
# 1 2011-01-02       0.0
# 2 2011-01-03       0.0
# 3 2011-01-04       0.0
# 4 2011-01-05       0.0

# %% [markdown]
# ### Extract average temperature

# %%
ave_temp = df_season['Prec(mm)']
ave_temp.index = df_season['Date']  # should set Date information as index
ave_temp_monthly = ave_temp.resample('M').mean()  # Obtain average per week
print(ave_temp_monthly.dtype)
display(ave_temp_monthly.head())
# Out:
# float64
# Date
# 2011-01-31    0.112903
# 2011-02-28    5.392857
# 2011-03-31    2.387097
# 2011-04-30    3.200000
# 2011-05-31    6.887097
# Freq: M, Name: Prec(mm), dtype: float64

# %% [markdown]
# ### See the original data

# %%
ave_temp_monthly.plot(kind='line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Seasonal decompose

# %%
result = sm.tsa.seasonal_decompose(ave_temp_monthly)  # Analysis of seasonality
result.observed.plot()  # original data
result.trend.plot()  # without seasonality
result.seasonal.plot()  # seasonality
result.resid.plot()  # residual
pfig = result.plot()  # all in one figure
