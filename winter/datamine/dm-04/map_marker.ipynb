# %% [markdown]
# ### Example of displaying map and marker using folium

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import folium

# %% [markdown]
# #### Show map and circle_markers

# %%
iniad_location = [35.780545, 139.715396]

map = folium.Map(location=iniad_location, zoom_start=15)

folium.Marker(location=iniad_location, popup='INIAD').add_to(map)
folium.CircleMarker(location=iniad_location, popup='INIAD', radius=50).add_to(map)
display(map)
map.save(outfile='iniad_marker.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb75963557bcbaeefaf8cd9f8c2e53f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb75963557bcbaeefaf8cd9f8c2e53f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb75963557bcbaeefaf8cd9f8c2e53f7 = L.map(
#                 &quot;map_cb75963557bcbaeefaf8cd9f8c2e53f7&quot;,
#                 {
#                     center: [35.780545, 139.715396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ceb18bfaeabca62c1a9ad5f5ca1db1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ceb18bfaeabca62c1a9ad5f5ca1db1f.addTo(map_cb75963557bcbaeefaf8cd9f8c2e53f7);
#
#
#             var marker_ee127e110fa095ce3eabd812755778ab = L.marker(
#                 [35.780545, 139.715396],
#                 {
# }
#             ).addTo(map_cb75963557bcbaeefaf8cd9f8c2e53f7);
#
#
#         var popup_7f9c3f9ee25dc16bbf21c40e856c0505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a7ed6ee7b4748aee0732b442eb43514 = $(`&lt;div id=&quot;html_6a7ed6ee7b4748aee0732b442eb43514&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INIAD&lt;/div&gt;`)[0];
#                 popup_7f9c3f9ee25dc16bbf21c40e856c0505.setContent(html_6a7ed6ee7b4748aee0732b442eb43514);
#
#
#
#         marker_ee127e110fa095ce3eabd812755778ab.bindPopup(popup_7f9c3f9ee25dc16bbf21c40e856c0505)
#         ;
#
#
#
#
#             var circle_marker_552759d825b26c00ff8cf3084edb1290 = L.circleMarker(
#                 [35.780545, 139.715396],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb75963557bcbaeefaf8cd9f8c2e53f7);
#
#
#         var popup_47e503c71ad60a65b2ffa649a73dcd2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cac8225a1ab9ca275154d97f43397f99 = $(`&lt;div id=&quot;html_cac8225a1ab9ca275154d97f43397f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INIAD&lt;/div&gt;`)[0];
#                 popup_47e503c71ad60a65b2ffa649a73dcd2f.setContent(html_cac8225a1ab9ca275154d97f43397f99);
#
#
#
#         circle_marker_552759d825b26c00ff8cf3084edb1290.bindPopup(popup_47e503c71ad60a65b2ffa649a73dcd2f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Using other tiles
# Builtin (Foliumに組み込まれているもの):
# https://github.com/python-visualization/folium/blob/main/examples/TilesExample.ipynb
#
# From others:
# https://maps.gsi.go.jp/development/ichiran.html
# https://leaflet-extras.github.io/leaflet-providers/preview/

# %% [markdown]
# Using Stamen Terrain

# %% [markdown]
# Using tiles from GIAJ (Geospatial Information Authority of Japan; 国土地理院)

# %%
iniad_location = [35.780545, 139.715396]

# Using Stamen Terrian
map = folium.Map(location=iniad_location, zoom_start=17,
                 tiles="https://cyberjapandata.gsi.go.jp/xyz/ort_riku10/{z}/{x}/{y}.png",
                 attr='国土地理院(GIAJ)')

folium.Marker(location=iniad_location, popup='INIAD').add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97089ddc7e60a54fed79f8c824d0a061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97089ddc7e60a54fed79f8c824d0a061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97089ddc7e60a54fed79f8c824d0a061 = L.map(
#                 &quot;map_97089ddc7e60a54fed79f8c824d0a061&quot;,
#                 {
#                     center: [35.780545, 139.715396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61ab9876c42ba07106ebb42a1e5aa1a9 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort_riku10/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662(GIAJ)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61ab9876c42ba07106ebb42a1e5aa1a9.addTo(map_97089ddc7e60a54fed79f8c824d0a061);
#
#
#             var marker_49e862dfd7039475a976ad4f33fdf663 = L.marker(
#                 [35.780545, 139.715396],
#                 {
# }
#             ).addTo(map_97089ddc7e60a54fed79f8c824d0a061);
#
#
#         var popup_cc61651be1a4c5b2cc88a0f5935dbc7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_105e955f86d53447af60da86a74e972f = $(`&lt;div id=&quot;html_105e955f86d53447af60da86a74e972f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INIAD&lt;/div&gt;`)[0];
#                 popup_cc61651be1a4c5b2cc88a0f5935dbc7a.setContent(html_105e955f86d53447af60da86a74e972f);
#
#
#
#         marker_49e862dfd7039475a976ad4f33fdf663.bindPopup(popup_cc61651be1a4c5b2cc88a0f5935dbc7a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
iniad_location = [35.780545, 139.715396]

# Using Stamen Terrian
map = folium.Map(location=iniad_location, zoom_start=17,
                 tiles="https://cyberjapandata.gsi.go.jp/xyz/ort/{z}/{x}/{y}.jpg",
                 attr='国土地理院(GIAJ)')

folium.Marker(location=iniad_location, popup='INIAD').add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e8a40cd5dc83c47ccef77dcd6ec3178 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e8a40cd5dc83c47ccef77dcd6ec3178&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e8a40cd5dc83c47ccef77dcd6ec3178 = L.map(
#                 &quot;map_7e8a40cd5dc83c47ccef77dcd6ec3178&quot;,
#                 {
#                     center: [35.780545, 139.715396],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c69253b0b7d3abe5b0e61d1799d6db1 = L.tileLayer(
#                 &quot;https://cyberjapandata.gsi.go.jp/xyz/ort/{z}/{x}/{y}.jpg&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u56fd\u571f\u5730\u7406\u9662(GIAJ)&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c69253b0b7d3abe5b0e61d1799d6db1.addTo(map_7e8a40cd5dc83c47ccef77dcd6ec3178);
#
#
#             var marker_7ebef62c51a42f213f06f7beca81ce1e = L.marker(
#                 [35.780545, 139.715396],
#                 {
# }
#             ).addTo(map_7e8a40cd5dc83c47ccef77dcd6ec3178);
#
#
#         var popup_6f7b2e3328b5021b2dff2114ca9d17b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21bd0027beaac5f24ca7f1b3265a6762 = $(`&lt;div id=&quot;html_21bd0027beaac5f24ca7f1b3265a6762&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;INIAD&lt;/div&gt;`)[0];
#                 popup_6f7b2e3328b5021b2dff2114ca9d17b1.setContent(html_21bd0027beaac5f24ca7f1b3265a6762);
#
#
#
#         marker_7ebef62c51a42f213f06f7beca81ce1e.bindPopup(popup_6f7b2e3328b5021b2dff2114ca9d17b1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
