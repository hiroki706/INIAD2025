# %% [markdown]
# # 問題
# 以下の空欄に有効数字三桁の数字のみを入れよ．
#
# >上空から質量$4.2[mg]$，半径$r=1.0[mm]$の球形の雨粒が，速度$v[m/s]$に比例した粘性抵抗$F[N]=6πηrv$を受けて静かに落下した．十分時間がたち，一定となったときの雨粒の速度$vf[m/s]$を求めよ．ただし，空気の粘性係数を$η=1.8×10-5[kg/(m･s)]$，重力加速度を$g=9.8[m/s2]$とする．
