# %%
import pandas as pd

dfx = pd.read_csv("./height.csv", sep=" ")

dfx.head()

# %%
dfx.corr()

# %%
import polars as pl

df = pl.read_csv("./height.csv", separator=" ")

df.head()

# %%
df["age":].corr()
